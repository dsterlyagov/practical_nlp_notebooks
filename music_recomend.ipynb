# %%
import json
from collections import Counter

import numpy as np
import pandas as pd
from sklearn.preprocessing import normalize

# %%
def load_data():
    with open('data/song.json') as inf:
        data = json.load(inf)
    data = pd.DataFrame(data)
    data.set_index('id', inplace=True)
    data['time_played'] = pd.to_datetime(data.time_played)
    data['user_sign_up_date'] = pd.to_datetime(data.user_sign_up_date)
    
    return data

# %%
data = load_data()

# %%
# сгруппируем по юзерам из различных штатов

# %%
user_counts = data.groupby('user_state').user_id.agg(lambda ids: len(np.unique(ids)))

# %%
user_counts
# Out:
# user_state
# Alabama            4
# Alaska             2
# Arizona            1
# Arkansas           2
# California        21
# Colorado           3
# Connecticut        1
# Florida            7
# Georgia            6
# Idaho              1
# Illinois           7
# Indiana            4
# Iowa               1
# Kansas             1
# Kentucky           3
# Louisiana          5
# Maryland           5
# Massachusetts      6
# Michigan           5
# Minnesota          4
# Mississippi        3
# Missouri           5
# Nebraska           1
# New Jersey         6
# New Mexico         1
# New York          23
# North Carolina     6
# North Dakota       1
# Ohio               9
# Oklahoma           2
# Oregon             3
# Pennsylvania       9
# Rhode Island       1
# South Carolina     3
# Tennessee          5
# Texas             15
# Utah               2
# Virginia           2
# Washington         2
# West Virginia      3
# Wisconsin          5
# Name: user_id, dtype: int64

# %%
user_counts.sort_values(ascending=False,inplace=True)

# %%
user_counts[:3]
# Out:
# user_state
# New York      23
# California    21
# Texas         15
# Name: user_id, dtype: int64

# %%
#Я определяю «среднее игровое событие в час» как метрику для измерения вовлеченности пользователей в состояние.

# %%
data.shape[0]
# Out:
# 4000

# %%
def count_by_state(df):
    total_played = df.shape[0]
    first_play_dt = df.time_played.min()
    last_play_dt = df.time_played.max()
    duration = last_play_dt - first_play_dt
    duration_hours = duration.total_seconds()/3600
    return pd.Series([first_play_dt, last_play_dt, duration, duration_hours, total_played], 
                    index=['first_play_dt', 'last_play_dt', 'duration', 'duration_hours', 'total_played'])

# %%
count_by_state(data)
# Out:
# first_play_dt     2015-06-01 05:02:54
# last_play_dt      2015-06-28 23:46:06
# duration             27 days 18:43:12
# duration_hours                 666.72
# total_played                     4000
# dtype: object

# %%
# теперь применим к каждому юзеру т.е. сгруппируем по штату пользователя
counts_by_states = data.groupby('user_state').apply(count_by_state)

# %%
counts_by_states
# Out:
#                      first_play_dt        last_play_dt         duration  \
# user_state
# Alabama        2015-06-01 14:17:56 2015-06-28 14:48:55 27 days 00:30:59
# Alaska         2015-06-01 18:48:18 2015-06-28 22:58:23 27 days 04:10:05
# Arizona        2015-06-01 13:05:17 2015-06-28 19:23:45 27 days 06:18:28
# Arkansas       2015-06-01 14:07:37 2015-06-28 17:40:11 27 days 03:32:34
# California     2015-06-01 06:33:03 2015-06-28 20:35:50 27 days 14:02:47
# Colorado       2015-06-01 14:57:48 2015-06-28 11:16:31 26 days 20:18:43
# Connecticut    2015-06-06 19:23:58 2015-06-28 13:16:32 21 days 17:52:34
# Florida        2015-06-01 09:29:39 2015-06-28 22:59:27 27 days 13:29:48
# Arkansas            651.542778            34
# California          662.046389           425
# Colorado            644.311944            54
# Connecticut         521.876111            16
# Florida             661.496667           180
# Georgia             662.932778           135
# Idaho               652.559444            26
# Illinois            653.865833           149
# Indiana             658.178889            55
# Iowa                635.843889            23
# Kansas              522.006944             8
# Kentucky            652.603889            78
# Louisiana           658.291944           105
# Maryland            657.138333           112
# Massachusetts       657.871944            91
# Michigan            657.854722            80
# Minnesota           616.550000            42
# Mississippi         657.996111            85
# Missouri            660.927500           127
# Nebraska            647.837500            36
# New Jersey          658.985556           117
# New Mexico          655.891111            17
# New York            663.365278           469
# North Carolina      658.768611           154
# North Dakota        657.211111            26
# Ohio                665.325278           209
# Oklahoma            647.235833            49
# Oregon              662.824444            62
# Pennsylvania        664.420000           179
# Rhode Island        623.500000            27
# South Carolina      661.346667            85
# Tennessee           653.255833           102
# Texas               662.325278           230
# Utah                655.719722            38
# Virginia            394.391389            17
# Washington          653.182222            41
# West Virginia       648.338611            38
# Wisconsin           661.755000            95

# %%
counts_by_states['hr_average'] = counts_by_states.total_played/counts_by_states.duration_hours

# %%
counts_by_states.sort_values(by='hr_average', ascending=False, inplace=True)

# %%
counts_by_states.head()
# Out:
#                  first_play_dt        last_play_dt         duration  \
# user_state
# New York   2015-06-01 06:14:45 2015-06-28 21:36:40 27 days 15:21:55
# California 2015-06-01 06:33:03 2015-06-28 20:35:50 27 days 14:02:47
# Texas      2015-06-01 06:09:04 2015-06-28 20:28:35 27 days 14:19:31
# Ohio       2015-06-01 05:02:54 2015-06-28 22:22:25 27 days 17:19:31
# Florida    2015-06-01 09:29:39 2015-06-28 22:59:27 27 days 13:29:48
#
#             duration_hours  total_played  hr_average
# user_state
# New York        663.365278           469    0.707001
# California      662.046389           425    0.641949
# Texas           662.325278           230    0.347261
# Ohio            665.325278           209    0.314132
# Florida         661.496667           180    0.272110

# %%
counts_by_states.tail()
# Out:
#                   first_play_dt        last_play_dt         duration  \
# user_state
# Iowa        2015-06-01 15:43:51 2015-06-28 03:34:29 26 days 11:50:38
# Arizona     2015-06-01 13:05:17 2015-06-28 19:23:45 27 days 06:18:28
# Connecticut 2015-06-06 19:23:58 2015-06-28 13:16:32 21 days 17:52:34
# New Mexico  2015-06-01 05:22:30 2015-06-28 13:15:58 27 days 07:53:28
# Kansas      2015-06-05 15:01:50 2015-06-27 09:02:15 21 days 18:00:25
#
#              duration_hours  total_played  hr_average
# user_state
# Iowa             635.843889            23    0.036172
# Arizona          654.307778            22    0.033623
# Connecticut      521.876111            16    0.030659
# New Mexico       655.891111            17    0.025919
# Kansas           522.006944             8    0.015325

# %%
user_sign = data.groupby('user_state')[['user_id','user_sign_up_date']].agg({'user_sign_up_date':'min'}).reset_index()

# %%
data
# Out:
#             user_id  user_state user_sign_up_date  \
# id
# GOQMMKSQQH      122   Louisiana        2015-05-16
# HWKKBQKNWI        3        Ohio        2015-05-01
# DKQSXVNJDH       35  New Jersey        2015-05-04
# HLHRIDQTUW      126    Illinois        2015-05-16
# SUKJCSBCYW        6  New Jersey        2015-05-01
# ...             ...         ...               ...
# MKVEXMRJGF      122   Louisiana        2015-05-16
# HMBEUWPBQI       76    New York        2015-05-08
# KIYDZUFUJN       68     Florida        2015-05-08
# BZNJXQSTTL      138     Alabama        2015-05-17
# LXJTCLWRUV      188    New York        2015-05-20
#
#                                       song_played         time_played
# id
# GOQMMKSQQH                               Hey Jude 2015-06-11 21:51:35
# HWKKBQKNWI                     We Can Work It Out 2015-06-06 16:49:19
# DKQSXVNJDH                   Back In the U.S.S.R. 2015-06-14 02:11:29
# HLHRIDQTUW                        P.s. I Love You 2015-06-08 12:26:10
# SUKJCSBCYW  Sgt. Pepper's Lonely Hearts Club Band 2015-06-28 14:57:00
# ...                                           ...                 ...
# MKVEXMRJGF                       Paperback Writer 2015-06-03 08:26:26
# HMBEUWPBQI              Reprise / Day in the Life 2015-06-14 15:46:04
# KIYDZUFUJN                               Get Back 2015-06-13 13:13:11
# BZNJXQSTTL                                  Help! 2015-06-01 17:01:40
# LXJTCLWRUV                               Birthday 2015-06-25 18:13:41
#
# [4000 rows x 5 columns]

# %%
user_sign
# Out:
#         user_state user_sign_up_date
# 0          Alabama        2015-05-01
# 1           Alaska        2015-05-12
# 2          Arizona        2015-05-12
# 3         Arkansas        2015-05-08
# 4       California        2015-05-04
# 5         Colorado        2015-05-19
# 6      Connecticut        2015-05-16
# 7          Florida        2015-05-04
# 8          Georgia        2015-05-02
# 9            Idaho        2015-05-19
# 10        Illinois        2015-05-05
# 11         Indiana        2015-05-12
# 12            Iowa        2015-05-19
# 13          Kansas        2015-05-19
# 14        Kentucky        2015-05-04
# 15       Louisiana        2015-05-06
# 16        Maryland        2015-05-02
# 17   Massachusetts        2015-05-02
# 18        Michigan        2015-05-02
# 19       Minnesota        2015-05-02
# 20     Mississippi        2015-05-02
# 21        Missouri        2015-05-09
# 22        Nebraska        2015-05-16
# 23      New Jersey        2015-05-01
# 24      New Mexico        2015-05-01
# 25        New York        2015-05-02
# 26  North Carolina        2015-05-01
# 27    North Dakota        2015-05-17
# 28            Ohio        2015-05-01
# 29        Oklahoma        2015-05-16
# 30          Oregon        2015-05-01
# 31    Pennsylvania        2015-05-02
# 32    Rhode Island        2015-05-19
# 33  South Carolina        2015-05-08
# 34       Tennessee        2015-05-08
# 35           Texas        2015-05-01
# 36            Utah        2015-05-03
# 37        Virginia        2015-05-17
# 38      Washington        2015-05-16
# 39   West Virginia        2015-05-07
# 40       Wisconsin        2015-05-04

# %%
pd.DataFrame(user_sign.values,columns=['user_state','user_id','sign_date']).sort_values(by='sign_date').head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-e47dacdcc806> in <module>
# ----> 1 pd.DataFrame(user_sign.values,columns=['user_state','user_id','sign_date']).sort_values(by='sign_date').head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (41, 2), indices imply (41, 3)
